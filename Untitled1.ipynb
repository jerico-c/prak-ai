# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (120, 4) (120,)
# Test set: (30, 4) (30,)

# %%
# from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred[0:5])
print(y_test[0:5])
# Out:
# [2 0 2 2 2]
# [2 0 2 2 2]

# %%
from sklearn import metrics
print("Test set Accuracy: ", metrics.accuracy_score(y_pred, y_test))
# Out:
# Test set Accuracy:  0.9666666666666667

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score


# Muat dataset Iris
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Plot distribusi setiap fitur
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
fig.suptitle('Distribusi Pengukuran Bunga Iris')

# Distribusi Panjang Sepal
axes[0, 0].hist(X[:, 0], bins=20, edgecolor='black')
axes[0, 0].set_title('Distribusi Panjang Sepal')

# Distribusi Lebar Sepal
axes[0, 1].hist(X[:, 1], bins=20, edgecolor='black')
axes[0, 1].set_title('Distribusi Lebar Sepal')

# Distribusi Panjang Petal
axes[1, 0].hist(X[:, 2], bins=20, edgecolor='black')
axes[1, 0].set_title('Distribusi Panjang Petal')

# Distribusi Lebar Petal
axes[1, 1].hist(X[:, 3], bins=20, edgecolor='black')
axes[1, 1].set_title('Distribusi Lebar Petal')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Visualisasi data: Sepal Length vs Sepal Width
plt.figure(figsize=(10, 6))
colors = ['red', 'yellow', 'green']
for i, color in enumerate(colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=target_names[i], edgecolor='k')

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.title('Sepal Length vs Sepal Width')
plt.show()

# Visualisasi data: Petal Length vs Petal Width
plt.figure(figsize=(10, 6))
colors = ['red', 'yellow', 'green']
for i, color in enumerate(colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 2], X[idx, 3], c=color, label=target_names[i], edgecolor='k')

plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend()
plt.title('Petal Length vs Petal Width')
plt.show()

# Visualisasi data: Sepal Length vs Petal Length
plt.figure(figsize=(10, 6))
colors = ['red', 'yellow', 'green']
for i, color in enumerate(colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 2], c=color, label=target_names[i], edgecolor='k')

plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend()
plt.title('Sepal Length vs Petal Length')
plt.show()

# Visualisasi data: Sepal Width vs Petal Width
plt.figure(figsize=(10, 6))
colors = ['red', 'yellow', 'green']
for i, color in enumerate(colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 1], X[idx, 3], c=color, label=target_names[i], edgecolor='k')

plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.legend()
plt.title('Sepal Width vs Petal Width')
plt.show()

target_names = iris.target_names
feature_names = iris.feature_names

# Buat DataFrame untuk analisis korelasi
df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

# Plot Correlation Heatmap
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Muat dataset Iris
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names
feature_names = iris.feature_names

# Buat DataFrame untuk analisis korelasi
df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

# Pisahkan dataset menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Buat classifier Gaussian Naive Bayes
gnb = GaussianNB()

# Latih classifier
gnb.fit(X_train, y_train)

# Prediksi label set pengujian
y_pred = gnb.predict(X_test)

# Hitung akurasi classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Akurasi: {accuracy:.2f}')

# Plot jumlah data per kelas
unique, counts = np.unique(y, return_counts=True)
plt.bar(target_names, counts, color=['red', 'yellow', 'green'])
plt.xlabel('Kelas')
plt.ylabel('Jumlah Data')
plt.title('Jumlah Data per Kelas')
plt.show()

# Plot Correlation Heatmap
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Akurasi: 0.98
